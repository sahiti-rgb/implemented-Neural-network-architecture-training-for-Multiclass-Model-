# %%
# Load Data from sklearn package
import sklearn
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('/content/Iris (2).csv')

X = df.iloc[:,:5].values
y = df.iloc[:,-1].values

# %%
#Prepare Feature Standardization
import keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow import keras
from tensorflow.keras import layers, optimizers
import tensorflow as tf
#One hot encoding
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(sparse_output = False,categories = 'auto')
y_encoded = enc.fit_transform(y.reshape(-1,1))

# apply train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size = 0.2, random_state = 1)

#y_enc = enc.transform(np.array(y_test).reshape(-1,1)) # Need to one-hot encode output for the neuralnetwork output layer
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(X_train)

# %%
Test_loss = []
Test_accuracy = []
Train_loss = []
Train_accuracy = []

# %%
# Building the Neural Network

#with no hidden layer
model = Sequential()
model.add(normalizer)
model.add(layers.Dense(units = 3, activation = 'softmax'))

# Compile Neural Network
model.compile(loss = "categorical_crossentropy",
                optimizer = "adam",
                metrics = ["accuracy"]
                )

model.summary()
# Train Model
history = model.fit(X_train,y_train,epochs = 10,batch_size = 2,validation_data = (X_test, y_test))
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
Test_loss.append(loss)
Test_accuracy.append(accuracy)

loss, accuracy = model.evaluate(X_train, y_train)
Train_loss.append(loss)
Train_accuracy.append(accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizati  (None, 5)                 11
#  on)
#
#  dense (Dense)               (None, 3)                 18
#
# =================================================================
# Total params: 29 (120.00 Byte)
# Trainable params: 18 (72.00 Byte)
# Non-trainable params: 11 (48.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 60/60 [==============================] - 1s 6ms/step - loss: 1.5253 - accuracy: 0.1333 - val_loss: 1.3064 - val_accuracy: 0.2000
# Epoch 2/10
# 60/60 [==============================] - 0s 2ms/step - loss: 1.3357 - accuracy: 0.2667 - val_loss: 1.1753 - val_accuracy: 0.2667
# Epoch 3/10
# 60/60 [==============================] - 0s 2ms/step - loss: 1.1770 - accuracy: 0.3000 - val_loss: 1.0666 - val_accuracy: 0.3667
# Epoch 4/10
# 60/60 [==============================] - 0s 2ms/step - loss: 1.0466 - accuracy: 0.4000 - val_loss: 0.9738 - val_accuracy: 0.4333
# Epoch 5/10
# 60/60 [==============================] - 0s 2ms/step - loss: 0.9369 - accuracy: 0.5000 - val_loss: 0.8996 - val_accuracy: 0.4667
# Epoch 6/10
# 60/60 [==============================] - 0s 2ms/step - loss: 0.8484 - accuracy: 0.5417 - val_loss: 0.8371 - val_accuracy: 0.4667
# Epoch 7/10
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7736 - accuracy: 0.6417 - val_loss: 0.7845 - val_accuracy: 0.5667
# Epoch 8/10
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7124 - accuracy: 0.6833 - val_loss: 0.7388 - val_accuracy: 0.5667
# Epoch 9/10
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6605 - accuracy: 0.6917 - val_loss: 0.7006 - val_accuracy: 0.5667
# Epoch 10/10
# 60/60 [==============================] - 0s 2ms/step - loss: 0.6174 - accuracy: 0.6917 - val_loss: 0.6680 - val_accuracy: 0.6000
# 1/1 [==============================] - 0s 133ms/step - loss: 0.6680 - accuracy: 0.6000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5962 - accuracy: 0.6917

# %%
# Building the Neural Network

#with 1 hidden layers
model = Sequential()
model.add(normalizer)
model.add(layers.Dense(8, activation = "relu", input_dim= 5))
model.add(layers.Dense(units = 3, activation = 'softmax'))

# Compile Neural Network
model.compile(loss = "categorical_crossentropy",
                optimizer = "adam",
                metrics = ["accuracy"]
                )

model.summary()
# Train Model
history = model.fit(X_train,y_train,epochs = 10,batch_size = 2,validation_data = (X_test, y_test))
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
Test_loss.append(loss)
Test_accuracy.append(accuracy)

loss, accuracy = model.evaluate(X_train, y_train)
Train_loss.append(loss)
Train_accuracy.append(accuracy)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizati  (None, 5)                 11
#  on)
#
#  dense_1 (Dense)             (None, 8)                 48
#
#  dense_2 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 86 (348.00 Byte)
# Trainable params: 75 (300.00 Byte)
# Non-trainable params: 11 (48.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 60/60 [==============================] - 1s 5ms/step - loss: 1.0346 - accuracy: 0.4500 - val_loss: 1.0088 - val_accuracy: 0.4333
# Epoch 2/10
# 60/60 [==============================] - 0s 2ms/step - loss: 0.8509 - accuracy: 0.5833 - val_loss: 0.8501 - val_accuracy: 0.5667
# Epoch 3/10
# 60/60 [==============================] - 0s 2ms/step - loss: 0.7086 - accuracy: 0.6917 - val_loss: 0.7264 - val_accuracy: 0.7000
# Epoch 4/10
# 60/60 [==============================] - 0s 2ms/step - loss: 0.5971 - accuracy: 0.7417 - val_loss: 0.6294 - val_accuracy: 0.7333
# Epoch 5/10
# 60/60 [==============================] - 0s 2ms/step - loss: 0.5130 - accuracy: 0.7750 - val_loss: 0.5568 - val_accuracy: 0.7333
# Epoch 6/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4491 - accuracy: 0.8250 - val_loss: 0.4932 - val_accuracy: 0.7333
# Epoch 7/10
# 60/60 [==============================] - 0s 2ms/step - loss: 0.3981 - accuracy: 0.8583 - val_loss: 0.4444 - val_accuracy: 0.7333
# Epoch 8/10
# 60/60 [==============================] - 0s 2ms/step - loss: 0.3562 - accuracy: 0.9083 - val_loss: 0.4021 - val_accuracy: 0.8000
# Epoch 9/10
# 60/60 [==============================] - 0s 5ms/step - loss: 0.3214 - accuracy: 0.9250 - val_loss: 0.3676 - val_accuracy: 0.8333
# Epoch 10/10
# 60/60 [==============================] - 0s 7ms/step - loss: 0.2915 - accuracy: 0.9333 - val_loss: 0.3367 - val_accuracy: 0.9333
# 1/1 [==============================] - 0s 146ms/step - loss: 0.3367 - accuracy: 0.9333
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2763 - accuracy: 0.9417

# %%
#with 2 hidden layers
model = Sequential()
model.add(normalizer)
model.add(layers.Dense(8, activation = "relu", input_dim= 5))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(layers.Dense(units = 3, activation = 'softmax'))

# Compile Neural Network
model.compile(loss = "categorical_crossentropy",
                optimizer = "adam",
                metrics = ["accuracy"]
                )

model.summary()
# Train Model
history = model.fit(X_train,y_train,epochs = 10,batch_size = 2,validation_data = (X_test, y_test))
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
Test_loss.append(loss)
Test_accuracy.append(accuracy)

loss, accuracy = model.evaluate(X_train, y_train)
Train_loss.append(loss)
Train_accuracy.append(accuracy)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizati  (None, 5)                 11
#  on)
#
#  dense_3 (Dense)             (None, 8)                 48
#
#  dense_4 (Dense)             (None, 8)                 72
#
#  dense_5 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 158 (636.00 Byte)
# Trainable params: 147 (588.00 Byte)
# Non-trainable params: 11 (48.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 60/60 [==============================] - 1s 5ms/step - loss: 1.0388 - accuracy: 0.6333 - val_loss: 0.9753 - val_accuracy: 0.6667
# Epoch 2/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.8554 - accuracy: 0.8250 - val_loss: 0.7778 - val_accuracy: 0.6667
# Epoch 3/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6333 - accuracy: 0.8167 - val_loss: 0.6009 - val_accuracy: 0.6667
# Epoch 4/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.4750 - accuracy: 0.8250 - val_loss: 0.4957 - val_accuracy: 0.7667
# Epoch 5/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.3822 - accuracy: 0.8333 - val_loss: 0.4237 - val_accuracy: 0.8000
# Epoch 6/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.3226 - accuracy: 0.8750 - val_loss: 0.3734 - val_accuracy: 0.8333
# Epoch 7/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2783 - accuracy: 0.9083 - val_loss: 0.3246 - val_accuracy: 0.8667
# Epoch 8/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2441 - accuracy: 0.9167 - val_loss: 0.2888 - val_accuracy: 0.8667
# Epoch 9/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.2150 - accuracy: 0.9167 - val_loss: 0.2610 - val_accuracy: 0.9000
# Epoch 10/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.1913 - accuracy: 0.9333 - val_loss: 0.2311 - val_accuracy: 0.9333
# 1/1 [==============================] - 0s 219ms/step - loss: 0.2311 - accuracy: 0.9333
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1777 - accuracy: 0.9417

# %%
# Building the Neural Network

#with 3 hidden layers
model = Sequential()
model.add(normalizer)
model.add(layers.Dense(8, activation = "relu", input_dim= 5))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(layers.Dense(units = 3, activation = 'softmax'))

# Compile Neural Network
model.compile(loss = "categorical_crossentropy",
                optimizer = "adam",
                metrics = ["accuracy"]
                )

model.summary()
# Train Model
history = model.fit(X_train,y_train,epochs = 10,batch_size = 2,validation_data = (X_test, y_test))
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
Test_loss.append(loss)
Test_accuracy.append(accuracy)

loss, accuracy = model.evaluate(X_train, y_train)
Train_loss.append(loss)
Train_accuracy.append(accuracy)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizati  (None, 5)                 11
#  on)
#
#  dense_6 (Dense)             (None, 8)                 48
#
#  dense_7 (Dense)             (None, 8)                 72
#
#  dense_8 (Dense)             (None, 8)                 72
#
#  dense_9 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 230 (924.00 Byte)
# Trainable params: 219 (876.00 Byte)
# Non-trainable params: 11 (48.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 60/60 [==============================] - 1s 8ms/step - loss: 1.0934 - accuracy: 0.4250 - val_loss: 1.0916 - val_accuracy: 0.2000
# Epoch 2/10
# 60/60 [==============================] - 0s 3ms/step - loss: 1.0598 - accuracy: 0.3667 - val_loss: 1.0587 - val_accuracy: 0.2000
# Epoch 3/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.9609 - accuracy: 0.4417 - val_loss: 0.9925 - val_accuracy: 0.5667
# Epoch 4/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.8338 - accuracy: 0.6833 - val_loss: 0.9234 - val_accuracy: 0.5667
# Epoch 5/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.7522 - accuracy: 0.7000 - val_loss: 0.8897 - val_accuracy: 0.5667
# Epoch 6/10
# 60/60 [==============================] - 0s 5ms/step - loss: 0.7074 - accuracy: 0.7417 - val_loss: 0.8360 - val_accuracy: 0.6000
# Epoch 7/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.6681 - accuracy: 0.8417 - val_loss: 0.7780 - val_accuracy: 0.7667
# Epoch 8/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.6269 - accuracy: 0.9167 - val_loss: 0.7311 - val_accuracy: 0.8333
# Epoch 9/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.5834 - accuracy: 0.9250 - val_loss: 0.6585 - val_accuracy: 0.9000
# Epoch 10/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.5389 - accuracy: 0.9500 - val_loss: 0.5969 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 160ms/step - loss: 0.5969 - accuracy: 1.0000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5116 - accuracy: 0.9750

# %%
# Building the Neural Network

#with 4 hidden layers
model = Sequential()
model.add(normalizer)
model.add(layers.Dense(8, activation = "relu", input_dim= 5))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(layers.Dense(units = 3, activation = 'softmax'))

# Compile Neural Network
model.compile(loss = "categorical_crossentropy",
                optimizer = "adam",
                metrics = ["accuracy"]
                )

model.summary()
# Train Model
history = model.fit(X_train,y_train,epochs = 10,batch_size = 2,validation_data = (X_test, y_test))
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
Test_loss.append(loss)
Test_accuracy.append(accuracy)

loss, accuracy = model.evaluate(X_train, y_train)
Train_loss.append(loss)
Train_accuracy.append(accuracy)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizati  (None, 5)                 11
#  on)
#
#  dense_10 (Dense)            (None, 8)                 48
#
#  dense_11 (Dense)            (None, 8)                 72
#
#  dense_12 (Dense)            (None, 8)                 72
#
#  dense_13 (Dense)            (None, 8)                 72
#
#  dense_14 (Dense)            (None, 3)                 27
#
# =================================================================
# Total params: 302 (1.18 KB)
# Trainable params: 291 (1.14 KB)
# Non-trainable params: 11 (48.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 60/60 [==============================] - 2s 8ms/step - loss: 1.0982 - accuracy: 0.3500 - val_loss: 1.0991 - val_accuracy: 0.5000
# Epoch 2/10
# 60/60 [==============================] - 0s 5ms/step - loss: 1.0803 - accuracy: 0.6917 - val_loss: 1.0553 - val_accuracy: 0.5667
# Epoch 3/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.9661 - accuracy: 0.6917 - val_loss: 0.8451 - val_accuracy: 0.5667
# Epoch 4/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.7947 - accuracy: 0.6917 - val_loss: 0.7248 - val_accuracy: 0.5667
# Epoch 5/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.7311 - accuracy: 0.6917 - val_loss: 0.6939 - val_accuracy: 0.5667
# Epoch 6/10
# 60/60 [==============================] - 0s 4ms/step - loss: 0.6880 - accuracy: 0.6917 - val_loss: 0.6690 - val_accuracy: 0.5667
# Epoch 7/10
# 60/60 [==============================] - 0s 5ms/step - loss: 0.6319 - accuracy: 0.6917 - val_loss: 0.6396 - val_accuracy: 0.5667
# Epoch 8/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.5578 - accuracy: 0.6917 - val_loss: 0.6044 - val_accuracy: 0.5667
# Epoch 9/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4894 - accuracy: 0.7500 - val_loss: 0.5662 - val_accuracy: 0.6000
# Epoch 10/10
# 60/60 [==============================] - 0s 3ms/step - loss: 0.4352 - accuracy: 0.8167 - val_loss: 0.5177 - val_accuracy: 0.6667
# 1/1 [==============================] - 0s 163ms/step - loss: 0.5177 - accuracy: 0.6667
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4132 - accuracy: 0.8250

# %%
#Test loss, test acc, train loss, train acc
print('  |TestL |TestA |TrainL| TrainA')
print("===============================")
max_test_accuracy = 0
min_test_loss = 1
min_Train_loss = 1
max_Train_accuracy = 0

for i in range(5):
  #print(f"{Test_loss[i]}|{Test_accuracy[i]}|{Train_loss[i]}|{Train_accuracy[i]}")
  if (Test_loss[i]< min_test_loss):
    min_test_loss = Test_loss[i]
    min_test_loss_index = i

  if (Test_accuracy[i] > max_test_accuracy):
    max_test_accuracy = Test_accuracy[i]
    max_test_accuracy_index = i

  if (Train_loss[i]< min_Train_loss):
    min_Train_loss = Train_loss[i]
    min_Train_loss_index = i

  if (Train_accuracy[i] > max_Train_accuracy):
    max_Train_accuracy = Train_accuracy[i]
    max_Train_accuracy_index = i

  print(i, "| %.2f |" % Test_loss[i], "%.2f |" % Test_accuracy[i], "%.2f |" % Train_loss[i], "%.2f |" % Train_accuracy[i] )

print()
print(max_test_accuracy,":",max_test_accuracy_index)
print(min_test_loss,":",min_test_loss_index)
print(min_Train_loss,":",min_Train_loss_index)
print(max_Train_accuracy,":",max_Train_accuracy_index)
print("\n")

print("----ANALYSIS----")
print(max(Test_loss))
print(max(Test_accuracy))
print(max(Train_loss))
print(max(Train_accuracy))

print("\n")

print(min(Test_loss))
print(min(Test_accuracy))
print(min(Train_loss))
print(min(Train_accuracy))
# Out:
#   |TestL |TestA |TrainL| TrainA
# ===============================
# 0 | 0.67 | 0.60 | 0.60 | 0.69 |
# 1 | 0.34 | 0.93 | 0.28 | 0.94 |
# 2 | 0.23 | 0.93 | 0.18 | 0.94 |
# 3 | 0.60 | 1.00 | 0.51 | 0.98 |
# 4 | 0.52 | 0.67 | 0.41 | 0.82 |
#
# 1.0 : 3
# 0.23108364641666412 : 2
# 0.17767280340194702 : 2
# 0.9750000238418579 : 3
#
#
# ----ANALYSIS----
# 0.6680452227592468
# 1.0
# 0.5961511135101318
# 0.9750000238418579
#
#
# 0.23108364641666412
# 0.6000000238418579
# 0.17767280340194702
# 0.6916666626930237
